# %%
#Import the libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read dataframe
df=pd.read_csv('D:\Customer churn problems\churn.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
#check for missing values
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
#statistical values
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
# group_bal        -0.010326   -0.014670     0.005851  0.024662 -0.010270
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.007246   0.000599        0.012044
# CustomerId      -0.012419       0.016972  -0.014025        0.001665
# CreditScore      0.006268       0.012238  -0.005458        0.025651
# Age              0.028308      -0.030680  -0.011721        0.085472
# Tenure          -0.012254       0.013444   0.022583       -0.028362
# Balance          1.000000      -0.304180  -0.014858       -0.010084
# NumOfProducts   -0.304180       1.000000   0.003183        0.009612
# HasCrCard       -0.014858       0.003183   1.000000       -0.011866
# IsActiveMember  -0.010084       0.009612  -0.011866        1.000000
# EstimatedSalary  0.012797       0.014204  -0.009933       -0.011421
# Exited           0.118533      -0.047820  -0.007138       -0.156128
# group_bal        0.972251      -0.283849  -0.014807       -0.010689
#
#                  EstimatedSalary    Exited  group_bal
# RowNumber              -0.005988 -0.016571  -0.010326
# CustomerId              0.015271 -0.006248  -0.014670
# CreditScore            -0.001384 -0.027094   0.005851
# Age                    -0.007201  0.285323   0.024662
# Tenure                  0.007784 -0.014001  -0.010270
# Balance                 0.012797  0.118533   0.972251
# NumOfProducts           0.014204 -0.047820  -0.283849
# HasCrCard              -0.009933 -0.007138  -0.014807
# IsActiveMember         -0.011421 -0.156128  -0.010689
# EstimatedSalary         1.000000  0.012097   0.011560
# Exited                  0.012097  1.000000   0.117511
# group_bal               0.011560  0.117511   1.000000

# %%
for col in df.columns:
    print(col, ':',len(df[col].value_counts()))
# Out:
# RowNumber : 10000
# CustomerId : 10000
# Surname : 2932
# CreditScore : 460
# Geography : 3
# Gender : 2
# Age : 70
# Tenure : 11
# Balance : 6382
# NumOfProducts : 4
# HasCrCard : 2
# IsActiveMember : 2
# EstimatedSalary : 9999
# Exited : 2

# %%
#Get customer churn count
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
#What is the percentage of stay and left customer??
num_retained=df[df.Exited==0.].shape[0]
num_churned=df[df.Exited==1].shape[0]
print(num_retained/(num_retained+num_churned)*100, '% of stay with the company')
print(num_churned/(num_retained+num_churned)*100, '% of customer left the company')
# Out:
# 79.63 % of stay with the company
# 20.369999999999997 % of customer left the company

# %%
# Age variable
df_age= df.groupby(by=['Age', 'Exited']).agg('count')
df_age.reset_index(drop=False, inplace=True)
df_age_inexit = df_age[df_age['Exited']==0][['Age', 'CreditScore']]
df_age_inexit=df_age_inexit.rename(columns={'CreditScore':'Count_inexit'})

df_age_exit=df_age[df_age['Exited']==1][['Age', 'CreditScore']]
df_age_exit=df_age_exit.rename(columns={'CreditScore': 'Count_exit'})

df1=pd.merge(df_age_inexit,df_age_exit,how='outer')
df1['Ratio']=df1.fillna(0,inplace=True)
df1['Ratio']=df1['Count_exit']*100/(df1['Count_inexit']+df1['Count_exit'])
df1
# Out:
#     Age  Count_inexit  Count_exit      Ratio
# 0    18            20         2.0   9.090909
# 1    19            26         1.0   3.703704
# 2    20            38         2.0   5.000000
# 3    21            50         3.0   5.660377
# 4    22            72        12.0  14.285714
# ..  ...           ...         ...        ...
# 65   83             1         0.0   0.000000
# 66   84             1         1.0  50.000000
# 67   85             1         0.0   0.000000
# 68   88             1         0.0   0.000000
# 69   92             2         0.0   0.000000
#
# [70 rows x 4 columns]

# %%
fig, ax= plt.subplots(figsize=[15,8])
sns.barplot(data=df1,x='Age', y='Ratio')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Ratio'>

# %% [markdown]
# The ratio of most of churned customers have their age lies in range of 45 to 65.
#
# Out of all Ages, 56 has the highest ratio of churned customer.
#
# 84 has a significant high rate of churn (abnormal)

# %%
def ratio(nation):
    return len(df[(df['Geography']==str(nation))&(df['Age']>=45)&(df['Age']<=65)])/len(df[df['Geography']==str(nation)])

# %%
# check for the rate of customer who churned between the age of 45 and 65 in each country
for i in ['Germany', 'France', 'Spain']:
    print(i,':','{:.2f}'.format(ratio(i)))
# Out:
# Germany : 0.25
# France : 0.19
# Spain : 0.20

# %%
# Tenure variable
df_ten_exit=df[df.Exited==1].groupby('Tenure').agg('count')
df_ten_exit.reset_index(drop=False,inplace=True)
df_ten_exit=df_ten_exit[['Tenure', 'CreditScore']]
df_ten_exit=df_ten_exit.rename(columns={'CreditScore':'Count'})

df_ten_inexit=df[df.Exited==0].groupby('Tenure').agg('count')
df_ten_inexit.reset_index(drop=False,inplace=True)
df_ten_inexit=df_ten_inexit[['Tenure', 'CreditScore']]
df_ten_inexit=df_ten_inexit.rename(columns={'CreditScore':'Count'})

df_ten= pd.merge(df_ten_exit,df_ten_inexit, how='outer',on='Tenure',suffixes=('_exit','_inexit'))
df_ten['Ratio']=df_ten['Count_exit']/(df_ten['Count_exit']+df_ten['Count_inexit'])
df_ten
# Out:
#     Tenure  Count_exit  Count_inexit     Ratio
# 0        0          95           318  0.230024
# 1        1         232           803  0.224155
# 2        2         201           847  0.191794
# 3        3         213           796  0.211100
# 4        4         203           786  0.205258
# 5        5         209           803  0.206522
# 6        6         196           771  0.202689
# 7        7         177           851  0.172179
# 8        8         197           828  0.192195
# 9        9         213           771  0.216463
# 10      10         101           389  0.206122

# %%
# Visualize the above dataset
fig, ax=plt.subplots(figsize=[10,6])
ax.bar(x=df_ten['Tenure'], height=df_ten['Count_inexit'],label='Count_inexit',color='blue')
ax.bar(x=df_ten['Tenure'], height=df_ten['Count_exit'],label='Count_exit',color='red')
ax2=ax.twinx()
ax2.plot(df_ten['Tenure'],df_ten['Ratio'],color='black')

# %% [markdown]
# Customers who have used the service for 10 years or less than a year are less in number compared to the other tenures.
# The churn rate fluctuates around 20% with the lowest value of 17% where tenure=7.

# %%
# Estimated salary 
df_sal_exited_male=df[df['Gender']=='Male'][['Exited', 'EstimatedSalary']]
df_sal_exited_female=df[df['Gender']=='Female'][['Exited', 'EstimatedSalary']]
df_sal_exited_male.groupby('Exited').agg('mean')
# Out:
#         EstimatedSalary
# Exited
# 0          99680.391827
# 1          99584.287272

# %%
df_sal_exited_female.groupby('Exited').agg('mean')
# Out:
#         EstimatedSalary
# Exited
# 0          99816.071486
# 1         102948.986093

# %%
#Geography
df_geo=df.groupby(by=['Geography']).agg('count')
df_geo.reset_index(inplace=True, drop=False)
df_geo=df_geo[['Geography', 'Age']]
df_geo.rename(inplace=True, columns={'Age':'count'})
df_geo
# Out:
#   Geography  count
# 0    France   5014
# 1   Germany   2509
# 2     Spain   2477

# %%
df_geo_exit=df[df['Exited']==1].groupby(by=['Geography']).agg('count')
df_geo_exit.reset_index(inplace=True,drop=False)
df_geo_exit=df_geo_exit[['Geography', 'Age']]
df_geo_exit.rename(inplace=True,columns={'Age':'count'})
df_geo['count_exit']=df_geo_exit['count']
df_geo['exit_ratio']=df_geo['count_exit']/df_geo['count']
df_geo
# Out:
#   Geography  count  count_exit  exit_ratio
# 0    France   5014         810    0.161548
# 1   Germany   2509         814    0.324432
# 2     Spain   2477         413    0.166734

# %%
df_f=df[df['Geography']=='France']
df_f.describe()
# Out:
#           RowNumber    CustomerId  CreditScore          Age       Tenure  \
# count   5014.000000  5.014000e+03  5014.000000  5014.000000  5014.000000
# mean    5025.228560  1.569065e+07   649.668329    38.511767     5.004587
# std     2873.666719  7.137584e+04    97.016799    10.469459     2.888475
# min        1.000000  1.556571e+07   350.000000    18.000000     0.000000
# 25%     2585.250000  1.562861e+07   582.000000    31.000000     2.000000
# 50%     5003.500000  1.569077e+07   653.000000    37.000000     5.000000
# 75%     7495.750000  1.575217e+07   717.000000    43.000000     7.000000
# max    10000.000000  1.581566e+07   850.000000    92.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    5014.000000    5014.000000  5014.000000     5014.000000
# mean    62092.636516       1.530913     0.706621        0.516753
# std     64133.565524       0.570347     0.455356        0.499769
# min         0.000000       1.000000     0.000000        0.000000
# 25%         0.000000       1.000000     0.000000        0.000000
# 50%     62153.500000       1.000000     1.000000        1.000000
# 75%    121444.877500       2.000000     1.000000        1.000000
# max    238387.560000       4.000000     1.000000        1.000000
#
#        EstimatedSalary       Exited
# count      5014.000000  5014.000000
# mean      99899.180814     0.161548
# std       57336.289016     0.368072
# min          90.070000     0.000000
# 25%       51399.190000     0.000000
# 50%       99132.310000     0.000000
# 75%      149295.360000     0.000000
# max      199929.170000     1.000000

# %%
df_s=df[df['Geography']=='Spain']
df_s.describe()
# Out:
#          RowNumber    CustomerId  CreditScore          Age       Tenure  \
# count  2477.000000  2.477000e+03  2477.000000  2477.000000  2477.000000
# mean   4950.667743  1.569192e+07   651.333872    38.890997     5.032297
# std    2881.454458  7.176554e+04    94.365051    10.446119     2.856660
# min       2.000000  1.556570e+07   350.000000    18.000000     0.000000
# 25%    2356.000000  1.562954e+07   587.000000    32.000000     3.000000
# 50%    5000.000000  1.569179e+07   651.000000    37.000000     5.000000
# 75%    7435.000000  1.575375e+07   715.000000    44.000000     8.000000
# max    9993.000000  1.581569e+07   850.000000    88.000000    10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count    2477.000000    2477.000000  2477.000000     2477.000000
# mean    61818.147763       1.539362     0.694792        0.529673
# std     64235.555208       0.564646     0.460588        0.499220
# min         0.000000       1.000000     0.000000        0.000000
# 25%         0.000000       1.000000     0.000000        0.000000
# 50%     61710.440000       2.000000     1.000000        1.000000
# 75%    121056.630000       2.000000     1.000000        1.000000
# max    250898.090000       4.000000     1.000000        1.000000
#
#        EstimatedSalary       Exited
# count      2477.000000  2477.000000
# mean      99440.572281     0.166734
# std       57103.678091     0.372813
# min         417.410000     0.000000
# 25%       50267.690000     0.000000
# 50%       99984.860000     0.000000
# 75%      147278.430000     0.000000
# max      199992.480000     1.000000

# %%
df_g=df[df['Geography']=='Germany']
df_g.describe()
# Out:
#          RowNumber    CustomerId  CreditScore          Age       Tenure  \
# count  2509.000000  2.509000e+03  2509.000000  2509.000000  2509.000000
# mean   5000.278996  1.569056e+07   651.453567    39.771622     5.009964
# std    2918.980192  7.322843e+04    98.168937    10.519143     2.935154
# min       8.000000  1.556578e+07   350.000000    18.000000     0.000000
# 25%    2461.000000  1.562740e+07   584.000000    32.000000     2.000000
# 50%    4997.000000  1.568989e+07   651.000000    38.000000     5.000000
# 75%    7583.000000  1.575573e+07   722.000000    45.000000     8.000000
# max    9999.000000  1.581566e+07   850.000000    84.000000    10.000000
#
#              Balance  NumOfProducts   HasCrCard  IsActiveMember  \
# count    2509.000000    2509.000000  2509.00000     2509.000000
# mean   119730.116134       1.519729     0.71383        0.497409
# std     27022.006157       0.619420     0.45206        0.500093
# min     27288.430000       1.000000     0.00000        0.000000
# 25%    102800.720000       1.000000     0.00000        0.000000
# 50%    119703.100000       1.000000     1.00000        0.000000
# 75%    137560.380000       2.000000     1.00000        1.000000
# max    214346.960000       4.000000     1.00000        1.000000
#
#        EstimatedSalary       Exited
# count      2509.000000  2509.000000
# mean     101113.435102     0.324432
# std       58263.011501     0.468256
# min          11.580000     0.000000
# 25%       51016.020000     0.000000
# 50%      102397.220000     0.000000
# 75%      151083.800000     1.000000
# max      199970.740000     1.000000

# %%
# Balance
sns.distplot(df['Balance'])
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Balance', ylabel='Density'>

# %% [markdown]
# A lot of blank account. Do they affect the churn rate?

# %%
#
df1=df[df['Balance']==0]
len(df1[df1['Exited']==1])/len(df1)
# Out:
# 0.13823610727121924

# %%
def group_bal(bal):
    if int(bal)==0:
        return 0
    if int(bal) in range (1,50000):
        return 1
    if int(bal) in range (50000,100000):
        return 50
    if int(bal) in range (100000,150000):
        return 100
    if int(bal) in range (150000,200000):
        return 150
    if int(bal) in range (200000,250000):
        return 200
    else:
        return 250

# %%
df['group_bal']=df['Balance'].map(group_bal)
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  group_bal
# 0           101348.88       1          0
# 1           112542.58       0         50
# 2           113931.57       1        150
# 3            93826.63       0          0
# 4            79084.10       0        100
# ...               ...     ...        ...
# 9995         96270.64       0          0
# 9996        101699.77       0         50
# 9997         42085.58       1          0
# 9998         92888.52       1         50
# 9999         38190.78       0        100
#
# [10000 rows x 15 columns]

# %%
df_group_bal= df.groupby(by='group_bal').agg('count')
df_group_bal.reset_index(inplace=True,drop=False)

labels=df_group_bal['group_bal']

fig1, ax1= plt.subplots()
ax1.pie(df_group_bal['Age'], labels=labels,autopct='%1.1f%%')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_bal=df.groupby(by=['group_bal','Exited']).agg('count')
df_bal.reset_index(drop=False,inplace=True)
df_bal=df_bal.rename(columns={'Age':'Count'})
df_bal=df_bal[['group_bal','Exited', 'Count']]
df_balance_=df_bal[df_bal['Exited']==0]
df_balance_ex=df_bal[df_bal['Exited']==1]

# %%
df_balance=pd.merge(df_balance_,df_balance_ex, how='outer',on='group_bal',suffixes=('_inex','_ex'))
df_balance
# Out:
#    group_bal  Exited_inex  Count_inex  Exited_ex  Count_ex
# 0          0          0.0      3117.0          1       500
# 1          1          0.0        49.0          1        26
# 2         50          0.0      1209.0          1       300
# 3        100          0.0      2843.0          1       987
# 4        150          0.0       730.0          1       205
# 5        200          0.0        15.0          1        18
# 6        250          NaN         NaN          1         1

# %%
df_balance.drop(columns=['Exited_ex', 'Exited_inex'], inplace=True)

# %%
df_balance['Ratio']=df_balance.Count_ex/(df_balance.Count_ex+df_balance.Count_inex)
df_balance
# Out:
#    group_bal  Count_inex  Count_ex     Ratio
# 0          0      3117.0       500  0.138236
# 1          1        49.0        26  0.346667
# 2         50      1209.0       300  0.198807
# 3        100      2843.0       987  0.257702
# 4        150       730.0       205  0.219251
# 5        200        15.0        18  0.545455
# 6        250         NaN         1       NaN

# %% [markdown]
# Prove that balance =0 doesn't equals high churn rate

# %%
#HasCrCard variable
df_creditcard=df.groupby(by=['Exited', 'HasCrCard']).agg('count')
df_creditcard.reset_index(inplace=True,drop=False)
df_creditcard=df_creditcard[['Exited','HasCrCard','Age']]
df_creditcard.rename(columns={'Age':'count'}, inplace=True)

df_creditcard=pd.merge(df_creditcard[df_creditcard['Exited']==0],df_creditcard[df_creditcard['Exited']==1],on='HasCrCard',how='outer',suffixes=('_inex','_ex'))
df_creditcard
# Out:
#    Exited_inex  HasCrCard  count_inex  Exited_ex  count_ex
# 0            0          0        2332          1       613
# 1            0          1        5631          1      1424

# %%
df_creditcard['Ratio']=df_creditcard['count_ex']/(df_creditcard['count_ex']+df_creditcard['count_inex'])
df_creditcard
# Out:
#    Exited_inex  HasCrCard  count_inex  Exited_ex  count_ex     Ratio
# 0            0          0        2332          1       613  0.208149
# 1            0          1        5631          1      1424  0.201843

# %% [markdown]
# The ratios are about the same so Whether a customer has a credit card or nor doesn't affect the churn rate

# %%
#creditscore variables
sns.distplot(df['CreditScore'])
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CreditScore', ylabel='Density'>

# %%
geo= ['France', 'Spain','Germany']
fig,axes= plt.subplots(1,3,figsize=(10,5))
for index,i in enumerate(geo):
    y=index%3
    sns.distplot(df[df['Geography']==i]["CreditScore"],ax=axes[y],axlabel=i)
plt.subplots_adjust(hspace=1,right=1.3)
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Is active member
sns.countplot(data=df, x='IsActiveMember',hue='Exited')
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %%
sns.countplot(data=df[df['Geography']=='Germany'],x='IsActiveMember',hue='Exited')
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %%
sns.countplot(data=df[df['Geography']=='Spain'],x='IsActiveMember',hue='Exited')
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %%
sns.countplot(data=df[df['Geography']=='France'],x='IsActiveMember',hue='Exited')
# Out:
# <AxesSubplot:xlabel='IsActiveMember', ylabel='count'>

# %% [markdown]
# Active members are less likely to churn

# %%
#NumofProduct
df_product=df.groupby(by=['Exited', 'NumOfProducts']).agg('count')
df_product.reset_index(inplace=True,drop=False)
df_product=df_product[['Exited','NumOfProducts','CreditScore']]
df_product=df_product.rename(columns={'CreditScore':'Count'})
df_product
# Out:
#    Exited  NumOfProducts  Count
# 0       0              1   3675
# 1       0              2   4242
# 2       0              3     46
# 3       1              1   1409
# 4       1              2    348
# 5       1              3    220
# 6       1              4     60

# %%
sns.barplot(data=df_product,x='NumOfProducts',y='Count',hue='Exited')
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Count'>

# %%
#GeovsGender
df_geo=df.groupby(by=['Geography','Exited','Gender']).agg('count')
df_geo=df_geo.rename(columns={'CreditScore':'Count'})
df_geo=df_geo[['Count']]
df_geo.reset_index(inplace=True,drop=False)
df_geo
# Out:
#    Geography  Exited  Gender  Count
# 0     France       0  Female   1801
# 1     France       0    Male   2403
# 2     France       1  Female    460
# 3     France       1    Male    350
# 4    Germany       0  Female    745
# 5    Germany       0    Male    950
# 6    Germany       1  Female    448
# 7    Germany       1    Male    366
# 8      Spain       0  Female    858
# 9      Spain       0    Male   1206
# 10     Spain       1  Female    231
# 11     Spain       1    Male    182

# %%
df_geo_ex=df_geo[df_geo['Exited']==1]
df_geo_ex['geo_gen']=df_geo_ex['Geography'] +'-'+df_geo_ex['Gender']
df_geo_ex
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23312\2120749578.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo_ex['geo_gen']=df_geo_ex['Geography'] +'-'+df_geo_ex['Gender']
#    Geography  Exited  Gender  Count         geo_gen
# 2     France       1  Female    460   France-Female
# 3     France       1    Male    350     France-Male
# 6    Germany       1  Female    448  Germany-Female
# 7    Germany       1    Male    366    Germany-Male
# 10     Spain       1  Female    231    Spain-Female
# 11     Spain       1    Male    182      Spain-Male

# %%
labels=df_geo_ex['geo_gen']
fig1, ax1=plt.subplots()
ax1.pie(df_geo_ex['Count'], labels=labels,autopct='%1.1f%%')
COLOR = 'white'
plt.rcParams.update({'text.color' : "white",
                     'axes.labelcolor' : "white"})
plt.show()

# %% [markdown]
# Overall, female has a higher percentage of churning
# Female in France and female in Germany takes up the highest percentage

# %%
df_geo_inex=df_geo[df_geo['Exited']==0]
df_geo_inex['geo_gen']=df_geo_inex['Geography'] +'-'+df_geo_inex['Gender']
df_geo_inex
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23312\4046197618.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo_inex['geo_gen']=df_geo_inex['Geography'] +'-'+df_geo_inex['Gender']
#   Geography  Exited  Gender  Count         geo_gen
# 0    France       0  Female   1801   France-Female
# 1    France       0    Male   2403     France-Male
# 4   Germany       0  Female    745  Germany-Female
# 5   Germany       0    Male    950    Germany-Male
# 8     Spain       0  Female    858    Spain-Female
# 9     Spain       0    Male   1206      Spain-Male

# %%
labels=df_geo_inex['geo_gen']
fig1, ax1=plt.subplots()
ax1.pie(df_geo_inex['Count'], labels=labels,autopct='%1.1f%%')
plt.show()

# %%
labels=df_geo_inex['geo_gen']
fig1, ax1=plt.subplots()
ax1.pie(df_geo_inex['Count'], labels=labels,autopct='%1.1f%%')
COLOR = 'white'
plt.rcParams.update({'text.color' : "white",
                     'axes.labelcolor' : "white"})
plt.show()

# %% [markdown]
# In the inexited group, France-male has the highest percentage (because French has the highest number of records, besides female churn more than male)
# In Germany, they have the least records but their churn rate is still high

# %%
df_sum=pd.merge(df_geo_ex,df_geo_inex, how='outer', on=['geo_gen','Geography', 'Gender'],suffixes=('_ex','_inex'))
df_sum['Ratio']=df_sum['Count_ex']/(df_sum['Count_ex']+df_sum['Count_inex'])
df_sum
# Out:
#   Geography  Exited_ex  Gender  Count_ex         geo_gen  Exited_inex  \
# 0    France          1  Female       460   France-Female            0
# 1    France          1    Male       350     France-Male            0
# 2   Germany          1  Female       448  Germany-Female            0
# 3   Germany          1    Male       366    Germany-Male            0
# 4     Spain          1  Female       231    Spain-Female            0
# 5     Spain          1    Male       182      Spain-Male            0
#
#    Count_inex     Ratio
# 0        1801  0.203450
# 1        2403  0.127134
# 2         745  0.375524
# 3         950  0.278116
# 4         858  0.212121
# 5        1206  0.131124

# %%
fig, ax=plt.subplots(figsize=[12,4])
sns.barplot(data=df_sum,x='geo_gen', y='Ratio')
# Out:
# <AxesSubplot:xlabel='geo_gen', ylabel='Ratio'>

# %% [markdown]
# Male: Germany has the highest male churn rate
# Female: All are high in 3 countries with the highest is Germany churn rate

# %%
#TenurevsGender
df_ten_gen=df.groupby(by=['Tenure','Gender','Exited']).agg('count')
df_ten_gen.reset_index(inplace=True, drop=False)
df_ten_gen=df_ten_gen[['Tenure','Gender','Exited','CreditScore']]
df_ten_gen=df_ten_gen.rename(columns={'CreditScore':'Count'})
df_ten_gen
# Out:
#     Tenure  Gender  Exited  Count
# 0        0  Female       0    149
# 1        0  Female       1     55
# 2        0    Male       0    169
# 3        0    Male       1     40
# 4        1  Female       0    348
# 5        1  Female       1    130
# 6        1    Male       0    455
# 7        1    Male       1    102
# 8        2  Female       0    367
# 9        2  Female       1    113
# 10       2    Male       0    480
# 11       2    Male       1     88
# 12       3  Female       0    350
# 13       3  Female       1    119
# 14       3    Male       0    446
# 15       3    Male       1     94
# 16       4  Female       0    335
# 17       4  Female       1    107
# 18       4    Male       0    451
# 19       4    Male       1     96
# 20       5  Female       0    324
# 21       5  Female       1    124
# 22       5    Male       0    479
# 23       5    Male       1     85
# 24       6  Female       0    352
# 25       6  Female       1    106
# 26       6    Male       0    419
# 27       6    Male       1     90
# 28       7  Female       0    364
# 29       7  Female       1    100
# 30       7    Male       0    487
# 31       7    Male       1     77
# 32       8  Female       0    324
# 33       8  Female       1    109
# 34       8    Male       0    504
# 35       8    Male       1     88
# 36       9  Female       0    312
# 37       9  Female       1    110
# 38       9    Male       0    459
# 39       9    Male       1    103
# 40      10  Female       0    179
# 41      10  Female       1     66
# 42      10    Male       0    210
# 43      10    Male       1     35

# %%
#Exited
sns.barplot(x=df_ten_gen[df_ten_gen['Exited']==1]['Tenure'],y=df_ten_gen['Count'],hue=df_ten_gen['Gender'])
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Count'>

# %%
#Inextied
sns.barplot(x=df_ten_gen[df_ten_gen['Exited']==0]['Tenure'],y=df_ten_gen['Count'],hue=df_ten_gen['Gender'])
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Count'>

# %%
df_a=df_ten_gen[df_ten_gen['Gender']=='Female']
df_b=df_ten_gen[df_ten_gen['Gender']=='Male']
df_a.merge(df_b,how='outer', on='Tenure', suffixes=('_female','_male'))
# Out:
#     Tenure Gender_female  Exited_female  Count_female Gender_male  \
# 0        0        Female              0           149        Male
# 1        0        Female              0           149        Male
# 2        0        Female              1            55        Male
# 3        0        Female              1            55        Male
# 4        1        Female              0           348        Male
# 5        1        Female              0           348        Male
# 6        1        Female              1           130        Male
# 7        1        Female              1           130        Male
# 8        2        Female              0           367        Male
# 9        2        Female              0           367        Male
# 10       2        Female              1           113        Male
# 11       2        Female              1           113        Male
# 12       3        Female              0           350        Male
# 13       3        Female              0           350        Male
# 14       3        Female              1           119        Male
# 15       3        Female              1           119        Male
# 16       4        Female              0           335        Male
# 17       4        Female              0           335        Male
# 18       4        Female              1           107        Male
# 19       4        Female              1           107        Male
# 20       5        Female              0           324        Male
# 21       5        Female              0           324        Male
# 22       5        Female              1           124        Male
# 23       5        Female              1           124        Male
# 24       6        Female              0           352        Male
# 25       6        Female              0           352        Male
# 26       6        Female              1           106        Male
# 27       6        Female              1           106        Male
# 28       7        Female              0           364        Male
# 29       7        Female              0           364        Male
# 30       7        Female              1           100        Male
# 31       7        Female              1           100        Male
# 32       8        Female              0           324        Male
# 33       8        Female              0           324        Male
# 34       8        Female              1           109        Male
# 35       8        Female              1           109        Male
# 36       9        Female              0           312        Male
# 37       9        Female              0           312        Male
# 38       9        Female              1           110        Male
# 39       9        Female              1           110        Male
# 40      10        Female              0           179        Male
# 41      10        Female              0           179        Male
# 42      10        Female              1            66        Male
# 43      10        Female              1            66        Male
#
#     Exited_male  Count_male
# 0             0         169
# 1             1          40
# 2             0         169
# 3             1          40
# 4             0         455
# 5             1         102
# 6             0         455
# 7             1         102
# 8             0         480
# 9             1          88
# 10            0         480
# 11            1          88
# 12            0         446
# 13            1          94
# 14            0         446
# 15            1          94
# 16            0         451
# 17            1          96
# 18            0         451
# 19            1          96
# 20            0         479
# 21            1          85
# 22            0         479
# 23            1          85
# 24            0         419
# 25            1          90
# 26            0         419
# 27            1          90
# 28            0         487
# 29            1          77
# 30            0         487
# 31            1          77
# 32            0         504
# 33            1          88
# 34            0         504
# 35            1          88
# 36            0         459
# 37            1         103
# 38            0         459
# 39            1         103
# 40            0         210
# 41            1          35
# 42            0         210
# 43            1          35

# %%
df_ten_gen_churn=df_ten_gen[df_ten_gen['Exited']==1]
df_ten_gen_not_churn=df_ten_gen[df_ten_gen['Exited']==0]
df_A=pd.merge(df_ten_gen_churn,df_ten_gen_not_churn, how='inner',on=['Tenure','Gender'],suffixes=['_churn','_not_churn'])
df_A['exit_ratio']= df_A['Count_churn']/(df_A['Count_churn']+df_A['Count_not_churn'])
df_A
# Out:
#     Tenure  Gender  Exited_churn  Count_churn  Exited_not_churn  \
# 0        0  Female             1           55                 0
# 1        0    Male             1           40                 0
# 2        1  Female             1          130                 0
# 3        1    Male             1          102                 0
# 4        2  Female             1          113                 0
# 5        2    Male             1           88                 0
# 6        3  Female             1          119                 0
# 7        3    Male             1           94                 0
# 8        4  Female             1          107                 0
# 9        4    Male             1           96                 0
# 10       5  Female             1          124                 0
# 11       5    Male             1           85                 0
# 12       6  Female             1          106                 0
# 13       6    Male             1           90                 0
# 14       7  Female             1          100                 0
# 15       7    Male             1           77                 0
# 16       8  Female             1          109                 0
# 17       8    Male             1           88                 0
# 18       9  Female             1          110                 0
# 19       9    Male             1          103                 0
# 20      10  Female             1           66                 0
# 21      10    Male             1           35                 0
#
#     Count_not_churn  exit_ratio
# 0               149    0.269608
# 1               169    0.191388
# 2               348    0.271967
# 3               455    0.183124
# 4               367    0.235417
# 5               480    0.154930
# 6               350    0.253731
# 7               446    0.174074
# 8               335    0.242081
# 9               451    0.175503
# 10              324    0.276786
# 11              479    0.150709
# 12              352    0.231441
# 13              419    0.176817
# 14              364    0.215517
# 15              487    0.136525
# 16              324    0.251732
# 17              504    0.148649
# 18              312    0.260664
# 19              459    0.183274
# 20              179    0.269388
# 21              210    0.142857

# %% [markdown]
# female churn rates are higher throughout the tenure years

# %%
sns.barplot(data=df_A,x='Tenure',y='exit_ratio',hue='Gender')
COLOR = 'black'
plt.rcParams.update({'text.color' : "black",
                     'axes.labelcolor' : "black"})

# %%
len(df[(df['Geography']=='Germany')&(df['Tenure']==7)])/len(df[df['Tenure']==7])
# Out:
# 0.2188715953307393

# %%
len(df[(df['Geography']=='Germany')&(df['Tenure']==9)])/len(df[df['Tenure']==9])
# Out:
# 0.2733739837398374

# %% [markdown]
# Germany's rate of both male and female at tenure=7 are lower than that at tenure=9. It lowers the overall churn rate at tenure=7.
# The people using 3 to 4 products have the churn rate higher than those who use 1 or 2 products

# %%
#Numbers of products by gender and geography
df_pro=df.groupby(by=['Exited','NumOfProducts','Geography']).agg('count')
df_pro.reset_index(inplace=True,drop=False)
df_pro=df_pro[['Exited','NumOfProducts','CreditScore','Geography']]
df_pro=df_pro.rename(columns={'CreditScore':'Count'})
df_pro
# Out:
#     Exited  NumOfProducts  Count Geography
# 0        0              1   1950    France
# 1        0              1    771   Germany
# 2        0              1    954     Spain
# 3        0              2   2232    France
# 4        0              2    914   Germany
# 5        0              2   1096     Spain
# 6        0              3     22    France
# 7        0              3     10   Germany
# 8        0              3     14     Spain
# 9        1              1    564    France
# 10       1              1    578   Germany
# 11       1              1    267     Spain
# 12       1              2    135    France
# 13       1              2    126   Germany
# 14       1              2     87     Spain
# 15       1              3     82    France
# 16       1              3     86   Germany
# 17       1              3     52     Spain
# 18       1              4     29    France
# 19       1              4     24   Germany
# 20       1              4      7     Spain

# %%
sns.barplot(data=df_pro[df_pro['Exited']==0],x='NumOfProducts',y='Count',hue='Geography')
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Count'>

# %% [markdown]
# All customers,who use 4 products,churn
# in all 3 countries, most of the customer are using 1 or 2 products
# Customer with 1, 2, and 3 products in Germany and Spain = 1/2 those in France

# %%
sns.barplot(data=df_pro[df_pro['Exited']==1],x='NumOfProducts',y='Count',hue='Geography')
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Count'>

# %% [markdown]
# This graph indicates that Germany and France have about the same number of churn customer, even higher at NumOfProduct=1 --> Germany has high churn rate (again :))

# %%
df_product=df.groupby(by=['Exited', 'NumOfProducts']).agg('count')
df_product.reset_index(inplace=True,drop=False)
df_product=df_product[['Exited','NumOfProducts','Age']]
df_product=df_product.rename(columns={'Age':'Count'})
df_product=pd.merge(df_product[df_product['Exited']==0],df_product[df_product['Exited']==1],on='NumOfProducts',how='outer',suffixes=('_inex','_ex'))
df_product.fillna(inplace=True, value=0)
df_product['Ratio']=(df_product['Count_ex'])/(df_product['Count_ex']+df_product['Count_inex'])
df_product['total_customer']=df_product['Count_inex']+df_product['Count_ex']
df_product
# Out:
#    Exited_inex  NumOfProducts  Count_inex  Exited_ex  Count_ex     Ratio  \
# 0          0.0              1      3675.0          1      1409  0.277144
# 1          0.0              2      4242.0          1       348  0.075817
# 2          0.0              3        46.0          1       220  0.827068
# 3          0.0              4         0.0          1        60  1.000000
#
#    total_customer
# 0          5084.0
# 1          4590.0
# 2           266.0
# 3            60.0

# %%
sns.barplot(data=df_product,x='NumOfProducts',y='Ratio')
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='Ratio'>

# %% [markdown]
# NumOfProducts = 4 has the highest rate of churn customer because there is only 1 customer in this categories.
# NumOfProducts =1 has the highest number of customer (5082 records). Following by NumOfProducts =2 with (4590 records). Group 1 churn rate is 4 times bigger than that of group 2.
# About 82.7% people in group 3 churn

# %%
sns.countplot(data=df,x='NumOfProducts',hue='Gender')
# Out:
# <AxesSubplot:xlabel='NumOfProducts', ylabel='count'>

# %% [markdown]
# In group 1 and 2 there are more women than men while the contrary happen in group 3 and 4.

# %%
# Detecting and hadling outliers
outlier_plot=['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary']
for i in outlier_plot:
    sns.boxplot(x=df[i])
    plt.show()

# %%
#Handling outlier
df_copy=df.copy()

# %%
#Find outlier
def detect_outlier(col):
#First quartile/percentile:
    first_qrt=np.quantile(df_copy[col],0.25)
#Third quartile/percentile:
    third_qrt=np.quantile(df_copy[col],0.75)
    lower_whisker= first_qrt-(third_qrt-first_qrt)*1.5
    print('Lower whisker:',lower_whisker)
    upper_whisker=third_qrt+(third_qrt-first_qrt)*1.5
    print('Upper whisker:',upper_whisker)

    outlier=df_copy.loc[(df_copy[col]<lower_whisker)|(df_copy[col]>upper_whisker)]
    print('Number of outliers:', len(outlier))
    print('% outliers: ',len(outlier)*100/len(df_copy),'%')
#return outlier

# %%
#Boxplot and find upper/lower bound
def boxplot(col):
    plt.figure(figsize=(8,5))
    sns.boxplot(y=col, data=df_copy)

# %%
#handle outliers with scipy.stats
df_cleaned=df_copy.copy()
import scipy.stats
def new_df(col,lower_bound,upper_bound):
    df_cleaned[col]=scipy.stats.mstats.winsorize(df_cleaned[col],limits=[lower_bound,upper_bound])

# %%
#Credit Score outlier
detect_outlier("CreditScore")
# Out:
# Lower whisker: 383.0
# Upper whisker: 919.0
# Number of outliers: 15
# % outliers:  0.15 %

# %%
boxplot("CreditScore")

# %%
new_df('CreditScore',0.0015,0)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y='CreditScore',data=df_cleaned)
# Out:
# <AxesSubplot:ylabel='CreditScore'>

# %%
#Age outlier
detect_outlier('Age')
# Out:
# Lower whisker: 14.0
# Upper whisker: 62.0
# Number of outliers: 359
# % outliers:  3.59 %

# %%
boxplot('Age')

# %%
new_df('Age',0,0.04)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y='Age',data=df_cleaned)
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
#NumOfProducts outlier
detect_outlier('NumOfProducts')
# Out:
# Lower whisker: -0.5
# Upper whisker: 3.5
# Number of outliers: 60
# % outliers:  0.6 %

# %%
boxplot('NumOfProducts')

# %%
new_df('NumOfProducts',0,0.006)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(y='NumOfProducts',data=df_cleaned)
# Out:
# <AxesSubplot:ylabel='NumOfProducts'>

# %%
df_cleaned
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  group_bal
# 0           101348.88       1          0
# 1           112542.58       0         50
# 2           113931.57       1        150
# 3            93826.63       0          0
# 4            79084.10       0        100
# ...               ...     ...        ...
# 9995         96270.64       0          0
# 9996        101699.77       0         50
# 9997         42085.58       1          0
# 9998         92888.52       1         50
# 9999         38190.78       0        100
#
# [10000 rows x 15 columns]

# %%
#MODEL
# Correlation
corr=df_cleaned.corr()
corr
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005794 -0.000443 -0.006495
# CustomerId        0.004202    1.000000     0.005429  0.008520 -0.014883
# CreditScore       0.005794    0.005429     1.000000 -0.007703  0.000721
# Age              -0.000443    0.008520    -0.007703  1.000000 -0.011163
# Tenure           -0.006495   -0.014883     0.000721 -0.011163  1.000000
# Balance          -0.009067   -0.012419     0.006389  0.033021 -0.012254
# NumOfProducts     0.006867    0.019728     0.012302 -0.041175  0.012878
# HasCrCard         0.000599   -0.014025    -0.005396 -0.012717  0.022583
# IsActiveMember    0.012044    0.001665     0.025537  0.072455 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001150 -0.007392  0.007784
# Exited           -0.016571   -0.006248    -0.026455  0.312436 -0.014001
# group_bal        -0.010326   -0.014670     0.005992  0.029519 -0.010270
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber       -0.009067       0.006867   0.000599        0.012044
# CustomerId      -0.012419       0.019728  -0.014025        0.001665
# CreditScore      0.006389       0.012302  -0.005396        0.025537
# Age              0.033021      -0.041175  -0.012717        0.072455
# Tenure          -0.012254       0.012878   0.022583       -0.028362
# Balance          1.000000      -0.318373  -0.014858       -0.010084
# NumOfProducts   -0.318373       1.000000   0.003821        0.010647
# HasCrCard       -0.014858       0.003821   1.000000       -0.011866
# IsActiveMember  -0.010084       0.010647  -0.011866        1.000000
# EstimatedSalary  0.012797       0.013860  -0.009933       -0.011421
# Exited           0.118533      -0.070736  -0.007138       -0.156128
# group_bal        0.972251      -0.297266  -0.014807       -0.010689
#
#                  EstimatedSalary    Exited  group_bal
# RowNumber              -0.005988 -0.016571  -0.010326
# CustomerId              0.015271 -0.006248  -0.014670
# CreditScore            -0.001150 -0.026455   0.005992
# Age                    -0.007392  0.312436   0.029519
# Tenure                  0.007784 -0.014001  -0.010270
# Balance                 0.012797  0.118533   0.972251
# NumOfProducts           0.013860 -0.070736  -0.297266
# HasCrCard              -0.009933 -0.007138  -0.014807
# IsActiveMember         -0.011421 -0.156128  -0.010689
# EstimatedSalary         1.000000  0.012097   0.011560
# Exited                  0.012097  1.000000   0.117511
# group_bal               0.011560  0.117511   1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
#Logistic Regression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import datasets, metrics
from sklearn.svm import SVC 
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.metrics import roc_auc_score,roc_curve
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
for i in ['CreditScore','Age','Balance','EstimatedSalary']:
    df_cleaned[i]=sc.fit_transform(df_cleaned[i].values.reshape(-1,1))

# %%
df_cleaned
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  \
# 0             1    15634602   Hargrave    -0.326878    France  Female
# 1             2    15647311       Hill    -0.440804     Spain  Female
# 2             3    15619304       Onio    -1.538636    France  Female
# 3             4    15701354       Boni     0.501675    France  Female
# 4             5    15737888   Mitchell     2.065569     Spain  Female
# ...         ...         ...        ...          ...       ...     ...
# 9995       9996    15606229   Obijiaku     1.247373    France    Male
# 9996       9997    15569892  Johnstone    -1.393640    France    Male
# 9997       9998    15584532        Liu     0.605244    France  Female
# 9998       9999    15682355  Sabbatini     1.257730   Germany    Male
# 9999      10000    15628319     Walker     1.464868    France  Female
#
#            Age  Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     0.342615       2 -1.225848              1          1               1
# 1     0.240011       1  0.117350              1          0               1
# 2     0.342615       8  1.333053              3          1               0
# 3     0.034803       1 -1.225848              2          0               0
# 4     0.445219       2  0.785728              1          1               1
# ...        ...     ...       ...            ...        ...             ...
# 9995  0.034803       5 -1.225848              2          1               0
# 9996 -0.375612      10 -0.306379              1          1               1
# 9997 -0.273008       7 -1.225848              1          0               1
# 9998  0.342615       3 -0.022608              2          1               0
# 9999 -1.093840       4  0.859965              1          1               0
#
#       EstimatedSalary  Exited  group_bal
# 0            0.021886       1          0
# 1            0.216534       0         50
# 2            0.240687       1        150
# 3           -0.108918       0          0
# 4           -0.365276       0        100
# ...               ...     ...        ...
# 9995        -0.066419       0          0
# 9996         0.027988       0         50
# 9997        -1.008643       1          0
# 9998        -0.125231       1         50
# 9999        -1.076370       0        100
#
# [10000 rows x 15 columns]

# %%
df_cleaned=df_cleaned.drop(columns=['group_bal','RowNumber','CustomerId','Surname'])
df_cleaned
# Out:
#       CreditScore Geography  Gender       Age  Tenure   Balance  \
# 0       -0.326878    France  Female  0.342615       2 -1.225848
# 1       -0.440804     Spain  Female  0.240011       1  0.117350
# 2       -1.538636    France  Female  0.342615       8  1.333053
# 3        0.501675    France  Female  0.034803       1 -1.225848
# 4        2.065569     Spain  Female  0.445219       2  0.785728
# ...           ...       ...     ...       ...     ...       ...
# 9995     1.247373    France    Male  0.034803       5 -1.225848
# 9996    -1.393640    France    Male -0.375612      10 -0.306379
# 9997     0.605244    France  Female -0.273008       7 -1.225848
# 9998     1.257730   Germany    Male  0.342615       3 -0.022608
# 9999     1.464868    France  Female -1.093840       4  0.859965
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1         0.021886       1
# 1                 1          0               1         0.216534       0
# 2                 3          1               0         0.240687       1
# 3                 2          0               0        -0.108918       0
# 4                 1          1               1        -0.365276       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0        -0.066419       0
# 9996              1          1               1         0.027988       0
# 9997              1          0               1        -1.008643       1
# 9998              2          1               0        -0.125231       1
# 9999              1          1               0        -1.076370       0
#
# [10000 rows x 11 columns]

# %%
df_cleaned_dum=pd.get_dummies(df_cleaned)

# %%
X=df_cleaned_dum.drop(columns=['Exited','HasCrCard','Balance'],axis=1)
y=df_cleaned_dum['Exited']
X=X.values
y=y.values

# %%
X_train_cleaned,X_test_cleaned,y_train_cleaned,y_test_cleaned=train_test_split(X,y,test_size=0.2,random_state=0)
model=LogisticRegression()
model.fit(X_train_cleaned,y_train_cleaned)
# Out:
# LogisticRegression()

# %%
accuracy_score(y_test_cleaned,model.predict(X_test_cleaned))
# Out:
# 0.822

# %%
cm=confusion_matrix(y_test_cleaned,model.predict(X_test_cleaned))
cm
# Out:
# array([[1531,   64],
#        [ 292,  113]], dtype=int64)

# %%
print('Result of LogisticRegression:\n ')
print(classification_report(y_test_cleaned,model.predict(X_test_cleaned)))
# Out:
# Result of LogisticRegression:
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      1595
#            1       0.64      0.28      0.39       405
#
#     accuracy                           0.82      2000
#    macro avg       0.74      0.62      0.64      2000
# weighted avg       0.80      0.82      0.79      2000

# %%
#DecisionTree
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier(max_depth=1)
clf.fit(X_train_cleaned,y_train_cleaned) 
accuracy_score(y_test_cleaned,clf.predict(X_test_cleaned))
# Out:
# 0.7975

# %%
cm_clf=confusion_matrix(y_test_cleaned,clf.predict(X_test_cleaned))
cm_clf
# Out:
# array([[1595,    0],
#        [ 405,    0]], dtype=int64)

# %%
accuracy_score(y_test_cleaned,model.predict(X_test_cleaned))
# Out:
# 0.822

# %%
print('Result of DecisionTreeClassifier: \n')
print(classification_report(y_test_cleaned,clf.predict(X_test_cleaned)))
# Out:
# Result of DecisionTreeClassifier:
#
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1595
#            1       0.00      0.00      0.00       405
#
#     accuracy                           0.80      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.64      0.80      0.71      2000
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
rd_fr=RandomForestClassifier()
rd_fr.fit(X_train_cleaned,y_train_cleaned)
accuracy_score(y_test_cleaned,rd_fr.predict(X_test_cleaned))
# Out:
# 0.861

# %%
cm_rdfr=confusion_matrix(y_test_cleaned,rd_fr.predict(X_test_cleaned))
cm_rdfr
# Out:
# array([[1522,   73],
#        [ 205,  200]], dtype=int64)

# %%
print('Result of RandomForestClassifier: \n')
print(classification_report(y_test_cleaned,rd_fr.predict(X_test_cleaned)))
# Out:
# Result of RandomForestClassifier:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      1595
#            1       0.73      0.49      0.59       405
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
